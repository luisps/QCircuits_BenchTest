# %%
import qiskit
print(qiskit.version.get_version_info())
#qiskit.__qiskit_version__
# Out:
# 2.3.0

# %%
from qiskit import QuantumCircuit, QuantumRegister

from circuit_generator import get_circuit

from math import pi

# %%
import struct
import os

# %%
# Parameterize this execution: circuitID
circuitID = 81612


######## 3x3 trivial circuit
if circuitID == 1:
    n= 3
    qc, num_qubits, layers, num_layers = get_circuit (circuitID, n)


######## 4x4 highly branching circuit
elif circuitID == 2:
    n= 4
    qc, num_qubits, layers, num_layers = get_circuit (circuitID, n)

######## n x n Hadamards circuit
elif circuitID == 3:
    n= 3
    qc, num_qubits, layers, num_layers = get_circuit (circuitID, n)

####### circuits 4 : different numbers of Hadamard: see 3

######## 4 x 4 Hadamards Ss Hadamards circuit
elif circuitID == 5:
    n= 4
    true_amplitude = 0.250000-0.000000j
    qc, num_qubits, layers, num_layers = get_circuit (circuitID, n)
######## 1 x 4 Hadamards Ts Hadamards circuit
elif circuitID == 51:
    n= 1
    true_amplitude = 0.70710678-0.0000j
    qc, num_qubits, layers, num_layers = get_circuit (circuitID, n)
######## 2 x 4 Hadamards Ts Hadamards circuit
elif circuitID == 52:
    n= 2
    true_amplitude = 0.50000000+0.00000000j
    qc, num_qubits, layers, num_layers = get_circuit (circuitID, n)
elif circuitID == 604:
    n= 4
    qc, num_qubits, layers, num_layers = get_circuit (600, n)
elif circuitID == 608:
    n= 8
    qc, num_qubits, layers, num_layers = get_circuit (600, n)
elif circuitID == 616:
    n= 16
    qc, num_qubits, layers, num_layers = get_circuit (600, n)
######## 2 x 4 Hadamards Ts Hadamards circuit
elif circuitID == 62:
    n= 2
    qc, num_qubits, layers, num_layers = get_circuit (circuitID, n)

######## variational EfficientSU2
elif circuitID == 19:
    n= 3
    reps = 1
    qc, num_qubits, layers, num_layers = get_circuit (circuitID, n, reps)

######## deeper variational EfficientSU2
elif circuitID == 191:
    n= 3
    reps = 2
    qc, num_qubits, layers, num_layers = get_circuit (19, n, reps)

######## deeper and larger variational EfficientSU2
elif circuitID == 192:
    n= 4
    reps = 2
    qc, num_qubits, layers, num_layers = get_circuit (19, n, reps)

######## deeper and larger variational EfficientSU2
elif circuitID == 193:
    n= 5
    reps = 1
    qc, num_qubits, layers, num_layers = get_circuit (19, n, reps)

######## deeper and larger variational EfficientSU2
elif circuitID == 194:
    n= 6
    reps = 1
    qc, num_qubits, layers, num_layers = get_circuit (19, n, reps)
######## deeper and larger variational EfficientSU2
elif circuitID == 195:
    n= 6
    reps = 2
    true_amplitude = -0.00514611-0.02104634j
    qc, num_qubits, layers, num_layers = get_circuit (19, n, reps)
######## deeper and larger variational EfficientSU2
elif circuitID == 196:
    n= 15
    reps = 2
    true_amplitude = -0.00514611-0.02104634j
    qc, num_qubits, layers, num_layers = get_circuit (19, n, reps)
######## deeper and larger variational EfficientSU2
elif circuitID == 197:
    n= 25
    reps = 2
    true_amplitude = -0.00514611-0.02104634j
    qc, num_qubits, layers, num_layers = get_circuit (19, n, reps)

######## random circuit
elif circuitID == 21: 
    n = 6
    depth = 5

    qc, num_qubits, layers, num_layers = get_circuit (circuitID, n, depth)

######## larger random circuit
elif circuitID == 211: 
    n = 7
    depth = 5

    qc, num_qubits, layers, num_layers = get_circuit (21, n, depth)

######## larger random circuit
elif circuitID == 212: 
    n = 8
    depth = 5

    qc, num_qubits, layers, num_layers = get_circuit (21, n, depth)

######## larger random circuit
elif circuitID == 213: 
    n = 9
    depth = 5

    qc, num_qubits, layers, num_layers = get_circuit (21, n, depth)

######## wider random circuit
elif circuitID == 214: 
    n = 15
    depth = 4

    qc, num_qubits, layers, num_layers = get_circuit (21, n, depth)
    
######## random circuit Clifford+T
elif circuitID == 23: 
    n = 11
    depth = 10
    Hpercent = 0.3

    qc, num_qubits, layers, num_layers = get_circuit (circuitID, n, depth, Hpercent)

######## random circuit Clifford+T
elif circuitID >= 232 and circuitID<=239: 
    n = (circuitID - 230)*2
    depth = n
    Hpercent = 0.3
    #Y = 3
    #true_amplitude = 0.01333677-0.00552427j

    qc, num_qubits, layers, num_layers = get_circuit (23, n, depth, Hpercent)


########### IQP
elif circuitID == 22:
    n= 4
    true_amplitude = 0.250000+0.000000j
    qc, num_qubits, layers, num_layers = get_circuit (circuitID, n)

########### test
elif circuitID == 100:
    true_amplitude = 0.250000+0.000000j
    qc, num_qubits, layers, num_layers = get_circuit (circuitID)
########### test
elif circuitID == 101:
    true_amplitude = 0.250000+0.000000j
    qc, num_qubits, layers, num_layers = get_circuit (circuitID)
########### test
elif circuitID == 102:
    qc, num_qubits, layers, num_layers = get_circuit (circuitID)
########### test
elif circuitID == 103:
    qc, num_qubits, layers, num_layers = get_circuit (circuitID)

########### IQP inversion test (kernel methods, overlap = p(0))
elif circuitID == 305:
    n= 5
    true_amplitude = -0.104462+0.106694j
    qc, num_qubits, layers, num_layers = get_circuit (300, n)
elif circuitID == 315:
    n= 15
    #true_amplitude = 0.250000+0.000000j
    qc, num_qubits, layers, num_layers = get_circuit (300, n)
elif circuitID == 325:
    n= 25
    #true_amplitude = 0.250000+0.000000j
    qc, num_qubits, layers, num_layers = get_circuit (300, n)
    
    
########### HSA
elif circuitID == 408:
    n= 8
    n_ccz = 1
    g = 2
    qc, num_qubits, layers, num_layers = get_circuit (400, n, n_ccz, g)
elif circuitID == 414:
    n= 14
    n_ccz = 1
    g = 2
    qc, num_qubits, layers, num_layers = get_circuit (400, n, n_ccz, g)
elif circuitID == 420:
    n= 20
    n_ccz = 1
    g = 2
    qc, num_qubits, layers, num_layers = get_circuit (400, n, n_ccz, g)
elif circuitID == 424:
    n= 24
    n_ccz = 1
    g = 2
    qc, num_qubits, layers, num_layers = get_circuit (400, n, n_ccz, g)
elif circuitID == 432:
    n= 32
    n_ccz = 1
    g = 2
    qc, num_qubits, layers, num_layers = get_circuit (400, n, n_ccz, g)
elif circuitID == 440:
    n= 40
    n_ccz = 1
    g = 2
    qc, num_qubits, layers, num_layers = get_circuit (400, n, n_ccz, g)
elif circuitID == 450:
    n= 50
    n_ccz = 1
    g = 2
    qc, num_qubits, layers, num_layers = get_circuit (400, n, n_ccz, g)
elif circuitID == 4100:
    n= 100
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 4101:
    n= 8
    n_ccz = 1
    g = 2
    Y = 7
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 4110:
    n= 11
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 4120:
    n= 20
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 4130:
    n= 30
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 4140:
    n= 40
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 4150:
    n= 50
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 4160:
    n= 60
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 4170:
    n= 70
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 4180:
    n= 80
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 4190:
    n= 90
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 41120:
    n= 120
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 41256:
    n= 256
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 41512:
    n= 512
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 411024:
    n= 1024
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 412048:
    n= 2048
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 414096:
    n= 4096
    n_ccz = 1
    g = 2
    Y = 1023
    qc, num_qubits, layers, num_layers = get_circuit (4100, n, n_ccz, g, Y)
elif circuitID == 508:   # random quasi-uniform
    n= 8
    nCycles = 6
    Y = 0
    qc, num_qubits, layers, num_layers = get_circuit (500, n, nCycles) 
elif circuitID == 510:   # random quasi-uniform
    n= 10
    nCycles = 7
    Y = 0
    qc, num_qubits, layers, num_layers = get_circuit (500, n, nCycles) 
elif circuitID == 512:   # random quasi-uniform
    n= 12
    nCycles = 8
    Y = 0
    qc, num_qubits, layers, num_layers = get_circuit (500, n, nCycles) 
elif circuitID == 516:   # random quasi-uniform
    n= 16
    nCycles = 12
    Y = 0
    qc, num_qubits, layers, num_layers = get_circuit (500, n, nCycles) 
elif circuitID == 525:   # random quasi-uniform
    n= 25
    nCycles = 18
    Y = 0
    qc, num_qubits, layers, num_layers = get_circuit (500, n, nCycles) 
elif circuitID == 7004:   # random square Clifford n=4
    n= 4
    n_T = 0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 7104:   # random square Clifford + 1T n=4
    n= 4
    n_T = 1
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 7204:   # random square Clifford + 2T n=4
    n= 4
    n_T = 2
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 7404:   # random square Clifford + 4T n=4
    n= 4
    n_T = 4
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 7008:   # random square Clifford n=8
    n= 8
    n_T = 0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 7108:   # random square Clifford n=8 + 1T
    n= 8
    n_T = 1
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 7208:   # random square Clifford n=8 + 2T
    n= 8
    n_T = 2
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 7408:   # random square Clifford n=8 + 4T
    n= 8
    n_T = 4
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 7808:   # random square Clifford n=8 + 8T
    n= 8
    n_T = 8
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 7012:   # random square Clifford n=12
    n= 12
    n_T = 0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 7112:   # random square Clifford n=12 + 1T
    n= 12
    n_T = 1
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 7212:   # random square Clifford n=12 + 2T
    n= 12
    n_T = 2
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 7412:   # random square Clifford n=12 + 4T
    n= 12
    n_T = 4
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 7812:   # random square Clifford n=12 + 8T
    n= 12
    n_T = 8
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 71212:   # random square Clifford n=12 + 12T
    n= 12
    n_T = 12
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (7000, n, n_T, seed) 
elif circuitID == 8044:   # square controlled phase - 4 qubits , 4 H, Z=0
    n= 4
    n_H = 4
    Ztheta_range = 0.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 8144:   # square controlled phase - 4 qubits , 4 H, Z=PI/6
    n= 4
    n_H = 4
    Ztheta_range = pi/6.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 8244:   # square controlled phase - 4 qubits , 4 H, Z=PI/4
    n= 4
    n_H = 4
    Ztheta_range = pi/4.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 8344:   # square controlled phase - 4 qubits , 4 H, Z=PI/3
    n= 4
    n_H = 4
    Ztheta_range = pi/3.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 

elif circuitID == 8036:   # square controlled phase - 6 qubits , 3 H, Z=0
    n= 6
    n_H = 3
    Ztheta_range = 0.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 8136:   # square controlled phase - 6 qubits , 3 H, Z=PI/6
    n= 6
    n_H = 3
    Ztheta_range = pi/6.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 8236:   # square controlled phase - 6 qubits , 3 H, Z=PI/4
    n= 6
    n_H = 3
    Ztheta_range = pi/4.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 8336:   # square controlled phase - 6 qubits , 3 H, Z=PI/3
    n= 6
    n_H = 3
    Ztheta_range = pi/3.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 8066:   # square controlled phase - 6 qubits , 6 H, Z=0
    n= 6
    n_H = 6
    Ztheta_range = 0.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 8166:   # square controlled phase - 6 qubits , 6 H, Z=PI/6
    n= 6
    n_H = 6
    Ztheta_range = pi/6.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 8266:   # square controlled phase - 6 qubits , 6 H, Z=PI/4
    n= 6
    n_H = 6
    Ztheta_range = pi/4.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 8366:   # square controlled phase - 6 qubits , 6 H, Z=PI/3
    n= 6
    n_H = 6
    Ztheta_range = pi/3.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 80312:   # square controlled phase - 12 qubits , 3 H, Z=0
    n= 12
    n_H = 3
    Ztheta_range = 0.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 81312:   # square controlled phase - 12 qubits , 3 H, Z=PI/6
    n= 12
    n_H = 3
    Ztheta_range = pi/6.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 82312:   # square controlled phase - 12 qubits , 3 H, Z=PI/4
    n= 12
    n_H = 3
    Ztheta_range = pi/4.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 83312:   # square controlled phase - 12 qubits , 3 H, Z=PI/3
    n= 12
    n_H = 3
    Ztheta_range = pi/3.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed)   
elif circuitID == 80612:   # square controlled phase - 12 qubits , 6 H, Z=0
    n= 12
    n_H = 6
    Ztheta_range = 0.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 81612:   # square controlled phase - 12 qubits , 6 H, Z=PI/6
    n= 12
    n_H = 6
    Ztheta_range = pi/6.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 82612:   # square controlled phase - 12 qubits , 6 H, Z=PI/4
    n= 12
    n_H = 6
    Ztheta_range = pi/4.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 83612:   # square controlled phase - 12 qubits , 6 H, Z=PI/3
    n= 12
    n_H = 6
    Ztheta_range = pi/3.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed)    
elif circuitID == 80912:   # square controlled phase - 12 qubits , 9 H, Z=0
    n= 12
    n_H = 9
    Ztheta_range = 0.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 81912:   # square controlled phase - 12 qubits , 9 H, Z=PI/6
    n= 12
    n_H = 9
    Ztheta_range = pi/6.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 82912:   # square controlled phase - 12 qubits , 9 H, Z=PI/4
    n= 12
    n_H = 9
    Ztheta_range = pi/4.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed) 
elif circuitID == 83912:   # square controlled phase - 12 qubits , 9 H, Z=PI/3
    n= 12
    n_H = 9
    Ztheta_range = pi/3.0
    seed = 2000
    qc, num_qubits, layers, num_layers = get_circuit (8000, n, n_H, Ztheta_range, seed)   
    
#for layer in layers:
#    print (layer)
#    for gate in layer:
#        print ("\tgate type {0} with {1} qubits: {2}".format(gate[0],len(gate[1]), gate[1]))
#
#    print ()

# Add measurement gates to the circuit
#qc.measure_all()

# %%
# draw the circuit

qc.draw('mpl')

# %%
# Execute the circuit using Sampler()
# Instantiate a new statevector simulation based sampler object.
#from qiskit.primitives import StatevectorSampler


#sampler = StatevectorSampler()

#shots = 2**20
# Start a job that will return shots .
#pub = (qc)
#job = sampler.run([pub], shots=shots)

# Extract the result for the 0th pub (this example only has one pub).
#result = job.result()[0]

#counts = result.data.meas.get_int_counts()


from qiskit.quantum_info import Statevector

sv = Statevector(qc)
#sv.draw(output='latex')
#print (sv.data)

# %%
format_string = "{0:8d} == {0:0" + str(num_qubits)+ "b} : {1:.6e} p={2:.3e}"

#ord_counts = dict(sorted(counts.items()))
#ord_probs = {}

#for k,v in ord_counts.items():
#    ord_probs[k] = v/shots

#    print (format_string.format(k, v/shots))

print (format_string.format(0, sv.data[0], abs(sv.data[0])**2))

#for s,v in enumerate(sv.data):
#    if abs(v) > 2**(-(num_qubits+2)):
#        print (format_string.format(s, v))
# Out:
#        0 == 000000000000 : 6.250000e-02+0.000000e+00j p=3.906e-03

# %%
print ("That\'s all, folks!")
# Out:
# That's all, folks!
